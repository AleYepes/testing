# %%
import pandas as pd

# %%
df = pd.read_csv('data/explorer.csv')
df.head(30)
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_6224\1500577829.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/explorer.csv')
#     search_id  region_id  city_id  user_id  page     filter     option
# 0           1       32.0  13614.0      NaN     1   latitude  43.265511
# 1           1       32.0  13614.0      NaN     1  longitude   -2.93381
# 2           1       32.0  13614.0      NaN     1      range        5.0
# 3           1       32.0  13614.0      NaN     1   scope_id        1.0
# 4           1       32.0  13614.0      NaN     1   scope_id        3.0
# 5           1       32.0  13614.0      NaN     1   scope_id        2.0
# 6           2       32.0  13614.0      NaN     1   latitude   43.26487
# 7           2       32.0  13614.0      NaN     1  longitude   -2.93305
# 8           2       32.0  13614.0      NaN     1      range        5.0
# ...

# %%
df['filter'].unique()
# Out:
# array(['latitude', 'longitude', 'range', 'scope_id', 'stage_id',
#        'price_id', 'segregation_id', 'vehicular_id', 'second_language_id',
#        'religion_id', 'service_id', 'educational_model_id', 'utm_content',
#        'skip', 'Nao', 'offset', 'limit', 'before', 'begin',
#        'starting_after', 'start', 'id', 'fields', 'filters_count',
#        'city_id', 'postal'], dtype=object)

# %%
df.loc[df['filter'] == 'religion_id'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.loc[df['filter'] == 'religion_id'].value_counts()
#
# NameError: name 'df' is not defined

# %% [markdown]
# AUTOMATE EVENT TRACKING
#
# Funnel GA4 es mas sobre visitas, no sobre eventos
#
# Queremos *enfocarnos en eventos* y visitas a pagina
# - track where users come from
#     - no aggregate, but by users
# - track what they click on
#
# [] Construct funnels
# []
#
# Python may be better to do
#
# Contact family success
#
# Investigate cookies
